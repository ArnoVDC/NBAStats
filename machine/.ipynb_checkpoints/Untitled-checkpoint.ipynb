# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ML libraries inladen
from sklearn import linear_model
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import Ridge
from sklearn.feature_selection import f_regression
from sklearn.covariance import EllipticEnvelope
# Voor statistische data visualisatie
import seaborn as sns; sns.set(color_codes=True)

# %%
dataset = pd.read_csv('Output.csv')
dataset.sample(frac=1).reset_index(drop=True)


dataset.head(10000)
# Out:
#                                          Player      Class  Season  Position  \
# 0               Doug McDermott\doug-mcdermott-1      Total       4       NaN
# 1                 Keydren Clark\keydren-clark-1       MAAC       4       NaN
# 2           Tyler Hansbrough\tyler-hansbrough-1        ACC       4       NaN
# 3                       J.J. Redick\jj-redick-1        ACC       4       NaN
# 4                       Tyler Haws\tyler-haws-1      Total       6       NaN
# 5                     Bo McCalebb\bo-mccalebb-1   Sun Belt       5       NaN
# 6                 Stephen Curry\stephen-curry-1   Southern       3       NaN
# 7                         Troy Bell\troy-bell-1   Big East       4       NaN
# 8             Henry Domercant\henry-domercant-1        OVC       4       NaN
# 9             Jimmer Fredette\jimmer-fredette-1        MWC       4       NaN
# 10          Andrew Goudelock\andrew-goudelock-1   Southern       4       NaN
# 11            Reggie Williams\reggie-williams-3  Big South       4       NaN
# 12              Keith Van Horn\keith-van-horn-1        WAC       4       NaN
# 13            Ronnie McCollum\ronnie-mccollum-1      Total       4       NaN
# 14              Jaycee Carroll\jaycee-carroll-1      Total       4       NaN
# 15            Charles Jenkins\charles-jenkins-1        CAA       4       NaN
# 16                    Caleb Green\caleb-green-1   Mid-Cont       4       NaN
# 17              Michael Watson\michael-watson-1   Mid-Cont       4       NaN
# 18                    Bonzi Wells\bonzi-wells-1        MAC       4       NaN
# 19              Luke Harangody\luke-harangody-1   Big East       4       NaN
# 20                  Eddie Benton\eddie-benton-1        NAC       4       NaN
# 21                D.J. Balentine\dj-balentine-1        MVC       4       NaN
# 22                  Nick Fazekas\nick-fazekas-1        WAC       4       NaN
# 23              Stefon Jackson\stefon-jackson-1       CUSA       4       NaN
# 24        Taylor Coppenrath\taylor-coppenrath-1        AEC       4       NaN
# 25                  Dallas Moore\dallas-moore-1      A-Sun       4       NaN
# 26                      Mike Jones\mike-jones-8      Total       6       NaN
# 27                Charles Jones\charles-jones-2      Total       5       NaN
# 28                  Kevin Foster\kevin-foster-2        WCC       5       NaN
# 29                  Kyle Singler\kyle-singler-1        ACC       4       NaN
# ...                                         ...        ...     ...       ...
# 9768            Michael Teller\michael-teller-1      A-Sun       5       NaN
# 9769               Andrien White\adrien-white-1       CUSA       2       NaN
# 9770            Keyshawn Woods\keyshawn-woods-1      Total       3       NaN
# 9771      Jonathan Beerbohm\jonathan-beerbohm-1   Big East       4       NaN
# 9772                Andy Bostick\andy-bostick-1        SEC       2       NaN
# 9773                      Tim Burns\tim-burns-2      Total       5       NaN
# 9774                Rian Everett\rian-everett-1  Big South       4       NaN
# 9775                  Ahmet Gueye\ahmet-gueye-1        WAC       2       NaN
# 9776        Courtney Jackson\courtney-jackson-1   Sun Belt       4       NaN
# 9777                  Rashard Lee\rashard-lee-1        SEC       4       NaN
# 9778        Michael Lindeman\michael-lindeman-1        MVC       4       NaN
# 9779                Paris London\paris-london-1      Total       5       NaN
# 9780                  Ryan Malone\ryan-malone-1      Total       2       NaN
# 9781            Maurice Miller\maurice-miller-1        ACC       4       NaN
# 9782                  Sean Miller\sean-miller-3  Southland       2       NaN
# 9783              Elijah Palmer\elijah-palmer-1       A-10       2       NaN
# 9784                  Willie Reed\willie-reed-1       A-10       2       NaN
# 9785            Curtis Shelton\curtis-shelton-1        OVC       2       NaN
# 9786          Aubrey Williams\aubrey-williams-2      Total       4       NaN
# 9787  Devaugntah Williams\devaugntah-williams-1     Big 12       2       NaN
# 9788                    Ryan Woods\ryan-woods-1        GWC       2       NaN
# 9789                  John Bowman\john-bowman-1  Southland       4       NaN
# 9790                Shon Coleman\shon-coleman-1        SEC       2       NaN
# 9791                  Nick Dillon\nick-dillon-1  Southland       2       NaN
# 9792                  DK Eldridge\dk-eldridge-1        WAC       2       NaN
# 9793            Williams Evans\williams-evans-1       SWAC       2       NaN
# 9794          Brandon Holcomb\brandon-holcomb-1  Big South       4       NaN
# 9795          Derrick Jackson\derrick-jackson-1        AEC       4       NaN
# 9796                    Kevin Love\kevin-love-1     Pac-10       1       NaN
# 9797                      Sean Paul\sean-paul-1        WAC       4       NaN
#
#                            School  Games   FG  FGA   2P  2PA   3P  3PA   FT  \
# 0                       Creighton     36  285  518  216  369   68  149  148
# 1                   Saint Peter's     29  241  601  133  303  108  298  172
# 2                  North Carolina     35  234  438  231  428    3    9  245
# 3                            Duke     34  206  476   92  195  114  281  165
# 4                   Brigham Young     23  152  319  125  248   27   71  120
# 5                     New Orleans     25  195  410  172  341   23   69  122
# 6                        Davidson     34  290  622  152  287  138  334  159
# 7                  Boston College     30  190  448  115  246   75  201  202
# 8                Eastern Illinois     30  215  475  144  299   71  176  148
# 9                   Brigham Young     34  209  460  135  272   74  188  156
# 10          College of Charleston     35  239  523  140  283   99  239   65
# 11    Virginia Military Institute     28  233  468  184  306   49  162  123
# 12                           Utah     30  222  426  171  298   51  128  138
# 13                 Centenary (LA)     28  205  494  119  257   86  237  133
# 14                     Utah State     33  220  430  127  232   92  198   98
# 15                        Hofstra     32  211  464  166  346   45  117  159
# 16                   Oral Roberts     32  205  381  203  373    2    7  213
# 17           Missouri-Kansas City     29  212  568  114  294   97  274   99
# 18                     Ball State     29  228  475  192  366   35  109  129
# 19                     Notre Dame     32  234  492  223  459   10   32  140
# 20                        Vermont     26  183  478  115  285   67  193  184
# 21                     Evansville     34  206  477  140  302   65  175  138
# 22                         Nevada     32  225  423  196  338   29   85  136
# 23                  Texas-El Paso     31  202  451  175  367   27   84  181
# 24                        Vermont     28  212  428  195  377   17   50  167
# 25                  North Florida     33  226  467  157  291   68  176   88
# 26                          Total     26  144  322   99  209   45  113   71
# 27                          Total     21  182  425  116  238   65  187   55
# 28                    Santa Clara     26  154  395   68  158   86  236   90
# 29                           Duke     37  203  469  136  285   66  184  124
# ...                           ...    ...  ...  ...  ...  ...  ...  ...  ...
# 9768                     Lipscomb     24   47  131   15   38   31   92   11
# 9769                    Charlotte     31  109  265   46  108   63  156   59
# 9770                        Total     21   84  172   54  105   30   66   28
# 9771               Boston College     29   63  136   56  110    7   25   36
# 9772               South Carolina     27  129  303   93  174   36  128   45
# 9773                        Total     23   50  119   38   78   12   40   22
# 9774                      Radford     22   50  125   21   51   28   74   41
# 9775                       Hawaii     28  132  249  132  249    0    0   76
# 9776         Arkansas-Little Rock     30   70  146   68  138    2    7   27
# 9777                    Tennessee     28   63  157   46  108   17   48   26
# 9778                    Creighton     30   59  128   44   92   15   36   36
# 9779                        Total     21   45  105   41   95    4    9   41
dataset.describe(
)
# Out:
#             Season  Position        Games           FG          FGA  \
# count  9798.000000       0.0  9798.000000  9798.000000  9798.000000
# mean      3.767708       NaN    27.925189   108.224434   241.244744
# std       0.911368       NaN     4.172656    38.742716    82.277028
# min       1.000000       NaN     8.000000    32.000000    80.000000
# 25%       3.000000       NaN    25.000000    78.000000   177.000000
# 50%       4.000000       NaN    28.000000   102.000000   228.000000
# 75%       4.000000       NaN    31.000000   132.000000   295.000000
# max       7.000000       NaN    39.000000   320.000000   777.000000
#
#                 2P          2PA           3P          3PA           FT  \
# count  9798.000000  9798.000000  9798.000000  9798.000000  9798.000000
# mean     79.808430   161.819657    28.077261    79.060318    64.649010
# std      39.381616    71.944819    22.608857    59.296062    30.872392
# min       3.000000     7.000000     0.000000     0.000000     5.000000
# 25%      51.000000   109.000000     8.000000    27.000000    42.000000
# 50%      74.000000   152.000000    26.000000    76.000000    59.000000
# 75%     102.000000   205.000000    43.000000   119.000000    82.000000
# max     295.000000   550.000000   138.000000   334.000000   245.000000
#
#                FTA          TRB          AST          STL          BLK  \
# count  9798.000000  9798.000000  9798.000000  9798.000000  9798.000000
# mean     90.516432   121.856297    54.453868    27.324556    11.868545
# std      41.563523    56.750830    36.232093    13.725795    14.844953
# min       8.000000    20.000000     3.000000     2.000000     0.000000
# 25%      59.000000    79.000000    28.000000    17.000000     3.000000
# 50%      84.000000   110.000000    45.000000    25.000000     7.000000
# 75%     115.000000   154.000000    72.000000    35.000000    15.000000
# max     324.000000   418.000000   263.000000   117.000000   164.000000
#
#                 PTS       Picked
# count  9.798000e+03  9798.000000
# mean   7.466778e+02     0.096346
# std    3.224353e+04     0.295080
# min    9.900000e+01     0.000000
# 25%    2.230000e+02     0.000000
# 50%    2.920000e+02     0.000000
# 75%    3.790000e+02     0.000000
# max    2.860950e+06     1.000000

# %%
dataset.corr()
f, ax = plt.subplots(figsize=(10, 8))
corr = dataset.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax,annot=True)

# %%
features =  list(dataset.columns[5:dataset.columns.size-1])
X = dataset[features].values 
y= dataset['Picked'].values

print(features)
# Out:
# ['Games', 'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'TRB', 'AST', 'STL', 'BLK', 'PTS']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state =0)

# %%
lregmodel = linear_model.LinearRegression()
lregmodel.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('coeffs: ',lregmodel.coef_)
print('intercept', lregmodel.intercept_)
# Out:
# coeffs:  [ -1.48860748e-03   1.17134309e-02  -5.08932478e-03  -7.24597422e-03
#    3.46202010e-03  -7.51775705e-03   4.08497017e-03   3.40803886e-03
#   -2.27063767e-03   4.53364138e-04   1.17672334e-03   3.63322018e-04
#    4.69242052e-03   3.52488829e-09]
# intercept -0.194344454301

# %%
y_predicted = lregmodel.predict(X_test)

## Mean Absolute Error
from sklearn.metrics import mean_absolute_error

MAE = mean_absolute_error(y_test,y_predicted)
print('MAE = ',MAE)

## Mean Squared Error
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test,y_predicted)
print('MSE = ',MSE)

## coefficient of determination = r2 score
from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_predicted)

print('r2 score = ',r2)
# Out:
# MAE =  0.160607198932
# MSE =  0.0690841847966
# r2 score =  0.171679761815
